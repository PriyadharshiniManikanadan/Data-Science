# %% [markdown]
# # Univariate Analysis
# ## 1. How to separate Quantitative & Qualitative columns

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Dataset informations
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# Expected Output
# quan = ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# qual = ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
# Quan columns = int & float
# Qual columns = object

# %%
# Check only datatypes for each columns
dataset.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
# Check datatype for Single Column
dataset["gender"].dtype
# Out:
# dtype('O')

# %%
dataset["mba_p"].dtype
# Out:
# dtype('float64')

# %%
# To get Columns List
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
# Check for loop to execute all the columns
for columnName in dataset.columns:
    print(columnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
# Check the Logic 
if dataset["gender"].dtype == 'object':
    print("qual")
else:
    print("quan")
# Out:
# qual

# %%
if dataset["mba_p"].dtype == 'object':
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
# Logic 
quan = []
qual = []
for columnName in dataset.columns:
    print(columnName)
    if dataset[columnName].dtype == 'object':
        print("qual")
        qual.append(columnName)
    else:
        print("quan")
        quan.append(columnName)
# Out:
# sl_no
# quan
# gender
# qual
# ssc_p
# quan
# ssc_b
# qual
# hsc_p
# quan
# hsc_b
# qual
# hsc_s
# qual
# degree_p
# quan
# degree_t
# qual
# workex
# qual
# etest_p
# quan
# specialisation
# qual
# mba_p
# quan
# status
# qual
# salary
# quan

# %%
# Logic without print statement
qual = []
quan = []
for columnName in dataset.columns:
    #print(columnName)
    if dataset[columnName].dtype == 'object':
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
quan,qual
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
# Logic into the Function

def quanQual(dataset):
    qual = []
    quan = []
    for columnName in dataset.columns:
        #print(columnName)
        if dataset[columnName].dtype == 'object':
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
# check the Function
quan,qual = quanQual(dataset)
quan,qual
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
# Function into Class
# Create Class ('Univariate_Analysis.py')
# Create'FairCopy_QuanQual.ipynb' and check the Magic of Class & Object by creating as a library

# %% [markdown]
# ## 2. Measure of Central Tendency

# %%
# Expected Output - Finding Mean, Median & Mode in Table for Quantitative Columns

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Check the description of the entire dataset
# Median & Mode is not a present
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
# Step by step Table creation
Descriptive = pd.DataFrame()
Descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Descriptive = pd.DataFrame(index=['Mean','Median','Mode'], columns = quan)
Descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
# Check Mean 
Descriptive = pd.DataFrame(index=['Mean','Median','Mode'], columns = quan)
for columnName in quan:
    Descriptive[columnName]['Mean'] = dataset[columnName].mean()
Descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\3633146995.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...

# %%
# Check for Median & Mode 
Descriptive = pd.DataFrame(index=['Mean','Median','Mode'], columns = quan)
for columnName in quan:
    Descriptive[columnName]['Mean'] = dataset[columnName].mean()    # First - Column , Second - Rows (Alphabetical order)
    Descriptive[columnName]['Median'] = dataset[columnName].median()
    Descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     # [0]  - to get only the numbers
Descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\684984243.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %% [markdown]
# ## 3. Percentile

# %%
import numpy as np

# %%
np.percentile(dataset['ssc_p'],50)

# This output Value denotes that 50% of data exists within 67
# For this dataset we can say that 50% of the students obtained marks within 67 score
# Out:
# 67.0

# %%
Descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %%
# Add Percentiles in Descriptive Table
Descriptive = pd.DataFrame(index=['Mean','Median','Mode','Q1:25%','Q2:50%',"Q3:75%", "99%","Q4:100%"], columns = quan)
for columnName in quan:
    Descriptive[columnName]['Mean'] = dataset[columnName].mean()    # First - Column , Second - Rows (Alphabetical order)
    Descriptive[columnName]['Median'] = dataset[columnName].median()
    Descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     # [0]  - to get only the numbers
Descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\1667313431.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
# Check for all 4 Quadrants(Percentile) 

Descriptive = pd.DataFrame(index=['Mean','Median','Mode','Q1:25%','Q2:50%',"Q3:75%","99%","Q4:100%"], columns = quan)
for columnName in quan:
    Descriptive[columnName]['Mean'] = dataset[columnName].mean()    
    Descriptive[columnName]['Median'] = dataset[columnName].median()
    Descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     
    Descriptive[columnName]['Q1:25%'] = dataset.describe()[columnName]["25%"]
    Descriptive[columnName]['Q2:50%'] = dataset.describe()[columnName]["50%"]
    Descriptive[columnName]['Q3:75%'] = dataset.describe()[columnName]["75%"]
    Descriptive[columnName]['99%'] = np.percentile(dataset[columnName],99)
    Descriptive[columnName]['Q4:100%'] = dataset.describe()[columnName]["max"]
Descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\3290539956.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...

# %% [markdown]
# ## 4. IQR ( Inter Quartile Range)

# %%
# Check the Outliers Range by finding IQR, 1.5 Rule, LEsser Range, Greater Range, Min & Max
# Formulas 
# IQR = Q3 - Q1
# 1.5 * IQR
# Lesser Range  = Q1 - (1.5 * IQR)
# Greater Range = Q3 + (1.5 * IQR)
# NOTE : Min values in the dataset of each column should not go below the Lesser range Outlier value
#        Max values in the dataset of each column should not go above the Greater range Outlier value

Descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', "Q3:75%", "99%", "Q4:100%",
                                  "IQR", "1.5-Rule", "Lesser_Outlier", "Greater_Outlier", "Min", "Max"], columns = quan)
for columnName in quan:
    Descriptive[columnName]['Mean'] = dataset[columnName].mean()    
    Descriptive[columnName]['Median'] = dataset[columnName].median()
    Descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     
    Descriptive[columnName]['Q1:25%'] = dataset.describe()[columnName]["25%"]
    Descriptive[columnName]['Q2:50%'] = dataset.describe()[columnName]["50%"]
    Descriptive[columnName]['Q3:75%'] = dataset.describe()[columnName]["75%"]
    Descriptive[columnName]['99%'] = np.percentile(dataset[columnName],99)
    Descriptive[columnName]['Q4:100%'] = dataset.describe()[columnName]["max"]
    Descriptive[columnName]['IQR'] = Descriptive[columnName]['Q3:75%'] - Descriptive[columnName]['Q1:25%']
    Descriptive[columnName]['1.5-Rule'] = 1.5 * Descriptive[columnName]['IQR']
    Descriptive[columnName]['Lesser_Outlier'] = Descriptive[columnName]['Q1:25%'] - Descriptive[columnName]['1.5-Rule']
    Descriptive[columnName]['Greater_Outlier'] = Descriptive[columnName]['Q3:75%'] + Descriptive[columnName]['1.5-Rule']
    Descriptive[columnName]['Min'] = dataset[columnName].min()
    Descriptive[columnName]['Max'] = dataset[columnName].max()
Descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\1563055470.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...

# %% [markdown]
# ## 5. Finding Outliers Column

# %%
Descriptive['hsc_p']['Min'] < Descriptive['hsc_p']['Lesser_Outlier']
# Out:
# True

# %%
Lesser = []
Greater = []
for columnName in quan:
    if Descriptive[columnName]['Min'] < Descriptive[columnName]['Lesser_Outlier']:
        Lesser.append(columnName)
    if Descriptive[columnName]['Max'] > Descriptive[columnName]['Greater_Outlier']:
        Greater.append(columnName)

# %%
Lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# ## Replacing Outliers

# %%
for columnName in Lesser:
    dataset[columnName][dataset[columnName]<Descriptive[columnName]['Lesser_Outlier']] = Descriptive[columnName]['Lesser_Outlier']

for columnName in Greater:
    dataset[columnName][dataset[columnName]>Descriptive[columnName]['Greater_Outlier']] = Descriptive[columnName]['Greater_Outlier']
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\860559301.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %% [markdown]
# ### Cross- Check whether all the outliers are changed

# %%
descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', "Q3:75%", "99%", "Q4:100%",
                                  "IQR", "1.5-Rule", "Lesser_Outlier", "Greater_Outlier", "Min", "Max"], columns = quan)
for columnName in quan:
    descriptive[columnName]['Mean'] = dataset[columnName].mean()    
    descriptive[columnName]['Median'] = dataset[columnName].median()
    descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     
    descriptive[columnName]['Q1:25%'] = dataset.describe()[columnName]["25%"]
    descriptive[columnName]['Q2:50%'] = dataset.describe()[columnName]["50%"]
    descriptive[columnName]['Q3:75%'] = dataset.describe()[columnName]["75%"]
    descriptive[columnName]['99%'] = np.percentile(dataset[columnName],99)
    descriptive[columnName]['Q4:100%'] = dataset.describe()[columnName]["max"]
    descriptive[columnName]['IQR'] = descriptive[columnName]['Q3:75%'] - descriptive[columnName]['Q1:25%']
    descriptive[columnName]['1.5-Rule'] = 1.5 * descriptive[columnName]['IQR']
    descriptive[columnName]['Lesser_Outlier'] = descriptive[columnName]['Q1:25%'] - descriptive[columnName]['1.5-Rule']
    descriptive[columnName]['Greater_Outlier'] = descriptive[columnName]['Q3:75%'] + descriptive[columnName]['1.5-Rule']
    descriptive[columnName]['Min'] = dataset[columnName].min()
    descriptive[columnName]['Max'] = dataset[columnName].max()
descriptive
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\2541471724.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...

# %%
descriptive['hsc_p']['Min'] < descriptive['hsc_p']['Lesser_Outlier']
# Out:
# False

# %%
LesserCheck = []
GreaterCheck = []
for columnName in quan:
    if descriptive[columnName]['Min'] < descriptive[columnName]['Lesser_Outlier']:
        LesserCheck.append(columnName)
    if descriptive[columnName]['Max'] > descriptive[columnName]['Greater_Outlier']:
        GreaterCheck.append(columnName)

# %%
# All the Outliers are changed with a Lesser range Outlier value and a Greater range Outlier value. 
# No Outliers in new dataset 'descriptive Table'

# %%
LesserCheck
# Out:
# []

# %%
GreaterCheck
# Out:
# []

# %% [markdown]
# ## 6. Frequency - Relative Frequency -  Cumulative Frequency

# %% [markdown]
# #### Get the Unique values to find all 3

# %%
FreqTable = pd.DataFrame(columns = ["Unique_Values", "Frequency", "Relative_Frequency", "Culmulative_Frequency"])
FreqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative_Frequency, Culmulative_Frequency]
# Index: []

# %%
# Get the Unique values for one column

FreqTable["Unique_Values"] = dataset["ssc_p"].value_counts().index
FreqTable["Frequency"] = dataset["ssc_p"].value_counts().values
FreqTable["Relative_Frequency"] = (FreqTable["Frequency"]/103)                          
FreqTable["Culmulative_Frequency"] = FreqTable["Relative_Frequency"].cumsum()
FreqTable
# Out:
#      Unique_Values  Frequency  Relative_Frequency  Culmulative_Frequency
# 0            62.00         11            0.106796               0.106796
# 1            63.00         10            0.097087               0.203883
# 2            67.00          9            0.087379               0.291262
# 3            52.00          9            0.087379               0.378641
# 4            73.00          9            0.087379               0.466019
# ..             ...        ...                 ...                    ...
# 98           69.70          1            0.009709               2.048544
# 99           80.92          1            0.009709               2.058252
# 100          83.00          1            0.009709               2.067961
# 101          86.50          1            0.009709               2.077670
# 102          80.60          1            0.009709               2.087379
#
# [103 rows x 4 columns]

# %%
# Create a Function to get the FreqTable for all the columns in dataset
def FreqTable(columnName,dataset):
    FreqTable = pd.DataFrame(columns = ["Unique_Values", "Frequency", "Relative_Frequency", "Culmulative_Frequency"])    
    FreqTable["Unique_Values"] = dataset[columnName].value_counts().index
    FreqTable["Frequency"] = dataset[columnName].value_counts().values
    FreqTable["Relative_Frequency"] = (FreqTable["Frequency"]/103)                          
    FreqTable["Culmulative_Frequency"] = FreqTable["Relative_Frequency"].cumsum()
    return FreqTable

# %%
# Check the Function 
FreqTable("mba_p",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  Culmulative_Frequency
# 0            56.70          3            0.029126               0.029126
# 1            66.94          2            0.019417               0.048544
# 2            59.47          2            0.019417               0.067961
# 3            60.44          2            0.019417               0.087379
# 4            68.07          2            0.019417               0.106796
# ..             ...        ...                 ...                    ...
# 200          67.00          1            0.009709               2.048544
# 201          64.27          1            0.009709               2.058252
# 202          57.65          1            0.009709               2.067961
# 203          59.42          1            0.009709               2.077670
# 204          60.22          1            0.009709               2.087379
#
# [205 rows x 4 columns]

# %% [markdown]
# ## 7. Histogram_Skewness_Kurtosis

# %%
dataset["hsc_p"].skew()  

# Positive Skew  
# Direction = mode -> median -> mean
# The mean is pulled toward the right tail, so it is the largest.
# Out:
# 0.16261050623024148

# %%
dataset["hsc_p"].kurtosis()

# Since the answer is <3
# The dispersion of the data denotes, the values range from the initial stage to the final stage
# Out:
# 0.08690077018906717

# %%
def Univariate(dataset,quan):
    descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', "Q3:75%", "99%", "Q4:100%",
                                  "IQR", "1.5-Rule", "Lesser_Outlier", "Greater_Outlier", "Min", "Max", "Skew", "Kurtosis"], columns = quan)
    for columnName in quan:
        descriptive[columnName]['Mean'] = dataset[columnName].mean()    
        descriptive[columnName]['Median'] = dataset[columnName].median()
        descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     
        descriptive[columnName]['Q1:25%'] = dataset.describe()[columnName]["25%"]
        descriptive[columnName]['Q2:50%'] = dataset.describe()[columnName]["50%"]
        descriptive[columnName]['Q3:75%'] = dataset.describe()[columnName]["75%"]
        descriptive[columnName]['99%'] = np.percentile(dataset[columnName],99)
        descriptive[columnName]['Q4:100%'] = dataset.describe()[columnName]["max"]
        descriptive[columnName]['IQR'] = descriptive[columnName]['Q3:75%'] - descriptive[columnName]['Q1:25%']
        descriptive[columnName]['1.5-Rule'] = 1.5 * descriptive[columnName]['IQR']
        descriptive[columnName]['Lesser_Outlier'] = descriptive[columnName]['Q1:25%'] - descriptive[columnName]['1.5-Rule']
        descriptive[columnName]['Greater_Outlier'] = descriptive[columnName]['Q3:75%'] + descriptive[columnName]['1.5-Rule']
        descriptive[columnName]['Min'] = dataset[columnName].min()
        descriptive[columnName]['Max'] = dataset[columnName].max()
        descriptive[columnName]['Skew'] = dataset[columnName].skew()
        descriptive[columnName]['Kurtosis'] = dataset[columnName].kurtosis()
    return descriptive

# %%
Univariate(dataset,quan)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\3761745616.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...

# %% [markdown]
# ## 8. Variance & Standard-Deviation

# %%
# Check Variance 
dataset['hsc_p'].var()
# Out:
# 112.06373065855242

# %%
# Check Standard Deviation
dataset['hsc_p'].std()
# Out:
# 10.58601580664569

# %%
def Univariate(dataset,quan):
    descriptive = pd.DataFrame(index=['Mean', 'Median', 'Mode', 'Q1:25%', 'Q2:50%', "Q3:75%", "99%", "Q4:100%",
                                      "IQR", "1.5-Rule", "Lesser_Outlier", "Greater_Outlier", "Min", "Max",
                                      "Skew", "Kurtosis", "Var", "StdD"], columns = quan)
    for columnName in quan:
        descriptive[columnName]['Mean'] = dataset[columnName].mean()    
        descriptive[columnName]['Median'] = dataset[columnName].median()
        descriptive[columnName]['Mode'] = dataset[columnName].mode()[0]     
        descriptive[columnName]['Q1:25%'] = dataset.describe()[columnName]["25%"]
        descriptive[columnName]['Q2:50%'] = dataset.describe()[columnName]["50%"]
        descriptive[columnName]['Q3:75%'] = dataset.describe()[columnName]["75%"]
        descriptive[columnName]['99%'] = np.percentile(dataset[columnName],99)
        descriptive[columnName]['Q4:100%'] = dataset.describe()[columnName]["max"]
        descriptive[columnName]['IQR'] = descriptive[columnName]['Q3:75%'] - descriptive[columnName]['Q1:25%']
        descriptive[columnName]['1.5-Rule'] = 1.5 * descriptive[columnName]['IQR']
        descriptive[columnName]['Lesser_Outlier'] = descriptive[columnName]['Q1:25%'] - descriptive[columnName]['1.5-Rule']
        descriptive[columnName]['Greater_Outlier'] = descriptive[columnName]['Q3:75%'] + descriptive[columnName]['1.5-Rule']
        descriptive[columnName]['Min'] = dataset[columnName].min()
        descriptive[columnName]['Max'] = dataset[columnName].max()
        descriptive[columnName]['Skew'] = dataset[columnName].skew()
        descriptive[columnName]['Kurtosis'] = dataset[columnName].kurtosis()
        descriptive[columnName]['Var'] = dataset[columnName].var()
        descriptive[columnName]['StdD'] = dataset[columnName].std()
    return descriptive

# %%
Univariate(dataset,quan)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14808\2935678530.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]['Mean'] = dataset[columnName].mean()
# ...
